# %%
fname=r'D:\Documents\Desktop\a.py'
# %load $fname

# %%
class F:
	a=3
	b=0
	for i in range(3):
		b+=a
	print('out of pri()')
	def pri(self):
		print('a is:', self.a, self.b)
	
	ar=[]
	@staticmethod
	def sm(x):
		ar.append(x)
	
print(F.a)
f=F()
F.a=5
print(F.a)
print(f.a)

f.pri()

from collections import deque
def solve(s):
	queue = deque()
	for c in s:
		if c == ')':
			if queue:
				queue.pop()
			# else:
				# return False
		elif c == '(':
			queue.append(c)
	return not bool(queue)

print solve(')()')


def check_brackets(s):
    counter = 0
    for chr in s:
        if chr == "(":
            counter += 1
        elif chr == ")":
            counter -= 1
            if counter < 0:
                return False
    return counter == 0

print check_brackets(')(')

import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax1 = fig.add_subplot(111)
x = np.linspace(-10,10,1000)
y = np.sin(x*np.pi/2)
ax1.plot(x,y)

ax2 = ax1.twiny()
tick_locations = ax1.get_xticks() - 5.
tick_labels = ax1.get_xticks()
print tick_locations, tick_labels, ax2.get_xlim()

# ax2.set_xlim(tick_locations[0], tick_locations[-1])
print ax2.get_xlim()
ax2.set_xticks(tick_locations[1:])
ax2.set_xticklabels(tick_labels[1:])
# ax2.set_xticklabels(['a', 'b'])

plt.show()

# import numpy as np
# import matplotlib.pyplot as plt

# fig = plt.figure()
# ax1 = fig.add_subplot(111)

# a = np.cos(2*np.pi*np.linspace(0, 1, 60.))
# ax1.plot(range(60), a)

# ax1.set_xlim(0, 60)
# ax1.set_xlabel("x")
# ax1.set_ylabel("y")

# ax2 = ax1.twiny()
# ax2.set_xlabel("x-transformed")
# ax2.set_xlim(0, 600)
# ax2.set_xticks([10, 30, 40])
# ax2.set_xticklabels(['7','8','99'])

# plt.show()
# Out:
# out of pri()
# 3
# 5
# 5
# ('a is:', 5, 9)
# True
# False
# [-15. -10.  -5.   0.   5.]
#  [-10.  -5.   0.   5.  10.] (0.0, 1.0)
# (0.0, 1.0)

# %%
# %save -f $fname 6
# Out:
# The following commands were written to file `D:\Documents\Desktop\a.py`:
# class F:
# 	a=3
# 	b=0
# 	for i in range(3):
# 		b+=a
# 	print('out of pri()')
# 	def pri(self):
# 		print('a is:', self.a, self.b)
#
# 	ar=[]
# 	@staticmethod
# 	def sm(x):
# 		ar.append(x)
#
# print(F.a)
# f=F()
# F.a=5
# print(F.a)
# print(f.a)
#
# f.pri()
#
# from collections import deque
# def solve(s):
# 	queue = deque()
# 	for c in s:
# 		if c == ')':
# 			if queue:
# 				queue.pop()
# 			# else:
# 				# return False
# 		elif c == '(':
# 			queue.append(c)
# 	return not bool(queue)
#
# print solve(')()')
#
#
# def check_brackets(s):
#     counter = 0
#     for chr in s:
#         if chr == "(":
#             counter += 1
#         elif chr == ")":
#             counter -= 1
#             if counter < 0:
#                 return False
#     return counter == 0
#
# print check_brackets(')(')
#
# import matplotlib.pyplot as plt
# import numpy as np
#
# fig = plt.figure()
# ax1 = fig.add_subplot(111)
# x = np.linspace(-10,10,1000)
# y = np.sin(x*np.pi/2)
# ax1.plot(x,y)
#
# ax2 = ax1.twiny()
# tick_locations = ax1.get_xticks() - 5.
# tick_labels = ax1.get_xticks()
# print tick_locations, tick_labels, ax2.get_xlim()
#
# # ax2.set_xlim(tick_locations[0], tick_locations[-1])
# print ax2.get_xlim()
# ax2.set_xticks(tick_locations[1:])
# ax2.set_xticklabels(tick_labels[1:])
# # ax2.set_xticklabels(['a', 'b'])
#
# plt.show()
#
# # import numpy as np
# # import matplotlib.pyplot as plt
#
# # fig = plt.figure()
# # ax1 = fig.add_subplot(111)
#
# # a = np.cos(2*np.pi*np.linspace(0, 1, 60.))
# # ax1.plot(range(60), a)
#
# # ax1.set_xlim(0, 60)
# # ax1.set_xlabel("x")
# # ax1.set_ylabel("y")
#
# # ax2 = ax1.twiny()
# # ax2.set_xlabel("x-transformed")
# # ax2.set_xlim(0, 600)
# # ax2.set_xticks([10, 30, 40])
# # ax2.set_xticklabels(['7','8','99'])
#
# # plt.show()
